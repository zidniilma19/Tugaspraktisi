# %% [markdown]
# <a href="https://colab.research.google.com/github/zidniilma19/Tugaspraktisi/blob/main/Multipel_linier_Regresion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as seaborninstance
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataset.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0        337          118                  4  4.5   4.5  9.65
# 1        324          107                  4  4.0   4.5  8.87
# 2        316          104                  3  3.0   3.5  8.00
# 3        322          110                  3  3.5   2.5  8.67
# 4        314          103                  2  2.0   3.0  8.21
#
#    Chance of Admit
# 0              0.92
# 1              0.76
# 2              0.72
# 3              0.80
# 4              0.65

# %%
dataset = pd.read_csv('/content/drive/MyDrive/data/Admission_Predict.csv')

# %%
data = dataset

# %%
data_train, data_test= train_test_split(data, test_size=0.2, random_state=0)
X_train = data_train.iloc[:,:-1].values
y_train = data_train.iloc[:,6].values
X_test = data_test.iloc[:,:-1].values
y_test = data_test.iloc[:,6].values

# %%
sns.pairplot(data_train)

# %%
sns.heatmap(data_train.corr(),annot = True)
# Out:
# <Axes: >

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
print(lr)
print(lr.intercept_,lr.coef_)
# Out:
# LinearRegression()
# -1.4458899929244335 [ 0.00252475  0.00194107  0.00703089 -0.00425489  0.02269074  0.12512472]

# %%
y_pred = lr.predict(X_test)
df = pd.DataFrame({'Actual (y_test)': y_test, 'Predicted (y_hat)': y_pred })
df.head(10)
# Out:
#    Actual (y_test)  Predicted (y_hat)
# 0             0.71           0.708818
# 1             0.70           0.702627
# 2             0.79           0.772407
# 3             0.73           0.622051
# 4             0.72           0.735828
# 5             0.48           0.611245
# 6             0.77           0.717143
# 7             0.71           0.652926
# 8             0.90           0.866874
# 9             0.94           0.918013

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.04985362867016845
# Mean Squared Error: 0.004901434759480486
# Root Mean Squared Error: 0.0700102475319184

# %%
print('R-squared', metrics.r2_score(y_test, y_pred))
# Out:
# R-squared 0.7302083954878599
